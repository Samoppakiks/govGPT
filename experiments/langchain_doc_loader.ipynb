# %%
# !pip install langchain

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"
from langchain.llms import OpenAI
llm = OpenAI(openai_api_key="OPENAI_API_KEY")

# %% [markdown]
# # Unstructured - English

# %%
from langchain.document_loaders import UnstructuredPDFLoader
loader = UnstructuredPDFLoader("/Users/saumya/Desktop/Programming/Data extraction/text/AllPDF/PdFextract copy 4/files/AIS(Study Leave)Regulations1950_NLTK.pdf")
data = loader.load()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/saumya/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# detectron2 is not installed. Cannot use the hi_res partitioning strategy. Falling back to partitioning with the fast strategy.

# %%
data
# Out:
# [Document(page_content="5.\n\n1THE ALL INDIA SERVICES (STUDY LEAVE) REGULATIONS, 1960\n\nIn pursuance of sub-rule (1) of rule 17 of the All India Services (Leave) Rules, 1955, the Central Government in consultation with the State Governments concerned hereby makes the following regulations namely:—\n\n1. Short title.—These regulations may be called the All India Services (Study\n\nLeave) Regulations, 1960.\n\n2. Definitions.—\n\n2(1)\n\nIn these regulations, unless the context otherwise requires:\n\n2(1) (a) „Audit Officer‟ means such officers as may be appointed by the\n\nComptroller and Auditor General of India.\n\n2(1)\n\n(b) „Head of Mission‟ means Ambassador, Charge d‟ Affairs, Ministers, Consul-General, High Commissioner and any other authority declared as such by the Central Government in the country in which the member of the Service undergoes a course of study or training.\n\n2(1)\n\n(c) „Pay and Accounts Officer‟ means such officer as may be appointed by the Ministries of D
# ...

# %% [markdown]
# # Unstructured - English - Scanned

# %%
# !pip install "detectron2@git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2"
# Out:
# ...
#   Cloning https://github.com/facebookresearch/detectron2.git (to revision e2ce8dc) to /private/var/folders/s_/m0k5_mm955jcf0x7qf9858sc0000gn/T/pip-install-ov9y15m9/detectron2_13ea8bcfb8734816a25b5ac25b7b9226
#   Running command git clone -q https://github.com/facebookresearch/detectron2.git /private/var/folders/s_/m0k5_mm955jcf0x7qf9858sc0000gn/T/pip-install-ov9y15m9/detectron2_13ea8bcfb8734816a25b5ac25b7b9226
#   WARNING: Did not find branch or tag 'e2ce8dc', assuming revision or ref.
#   Running command git checkout -q e2ce8dc
#   Resolved https://github.com/facebookresearch/detectron2.git to commit e2ce8dc
# ...
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# ...
#   Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# ...
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# ...
#   Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# ...
#   Using cached tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
# ...
#   Using cached fvcore-0.1.5.post20221221.tar.gz (50 kB)
# ...

# %%
from langchain.document_loaders import UnstructuredPDFLoader
loader = UnstructuredPDFLoader("/Users/saumya/Desktop/Programming/Data extraction/text/AllPDF/PdFextract copy 4/files/Ex-India Leave rules Nltk.pdf")
data = loader.load()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [13], line 3
#       1 from langchain.document_loaders import UnstructuredPDFLoader
#       2 loader = UnstructuredPDFLoader("/Users/saumya/Desktop/Programming/Data extraction/text/AllPDF/PdFextract copy 4/files/Ex-India Leave rules Nltk.pdf")
# ----> 3 data = loader.load()
#
# File ~/miniconda3/lib/python3.9/site-packages/langchain/document_loaders/unstructured.py:61, in UnstructuredBaseLoader.load(self)
#      59 def load(self) -> List[Document]:
#      60     """Load file."""
# ---> 61     elements = self._get_elements()
#      62     if self.mode == "elements":
#      63         docs: List[Document] = list()
#
# File ~/miniconda3/lib/python3.9/site-packages/langchain/document_loaders/pdf.py:21, in UnstructuredPDFLoader._get_elements(self)
#      18 def _get_elements(self) -> List:
# ...

# %%
data
# Out:
# [Document(page_content='', lookup_str='', metadata={'source': '/Users/saumya/Desktop/Programming/Data extraction/text/AllPDF/PdFextract copy 4/files/Ex-India Leave rules Nltk.pdf'}, lookup_index=0)]

# %% [markdown]
# ## Thoughts :

# %% [markdown]
# Seems to work well with real English PDFs, failed with scanned English even after installing delectron

# %% [markdown]
# # PyMuPDF - English - Scanned

# %%
from langchain.document_loaders import PyMuPDFLoader
loader = PyMuPDFLoader("/Users/saumya/Desktop/Programming/Data extraction/text/AllPDF/PdFextract copy 4/files/Ex-India Leave rules Nltk.pdf")
data = loader.load()
data
# Out:
# [Document(page_content='', lookup_str='', metadata={'file_path': '/Users/saumya/Desktop/Programming/Data extraction/text/AllPDF/PdFextract copy 4/files/Ex-India Leave rules Nltk.pdf', 'page_number': 1, 'total_pages': 7, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': 'Adobe Scan for iOS 23.03.07', 'producer': 'Adobe Scan for iOS 23.03.07', 'creationDate': '', 'modDate': '', 'trapped': ''}, lookup_index=0),
#  Document(page_content='', lookup_str='', metadata={'file_path': '/Users/saumya/Desktop/Programming/Data extraction/text/AllPDF/PdFextract copy 4/files/Ex-India Leave rules Nltk.pdf', 'page_number': 2, 'total_pages': 7, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': 'Adobe Scan for iOS 23.03.07', 'producer': 'Adobe Scan for iOS 23.03.07', 'creationDate': '', 'modDate': '', 'trapped': ''}, lookup_index=0),
# ...

# %% [markdown]
# # PDF Miner - English - Scanned

# %%
from langchain.document_loaders import PDFMinerLoader
loader = PDFMinerLoader("/Users/saumya/Desktop/Programming/Data extraction/text/AllPDF/PdFextract copy 4/files/Ex-India Leave rules Nltk.pdf")
data = loader.load()
data
# Out:
# [Document(page_content='\x0c\x0c\x0c\x0c\x0c\x0c\x0c', lookup_str='', metadata={'source': '/Users/saumya/Desktop/Programming/Data extraction/text/AllPDF/PdFextract copy 4/files/Ex-India Leave rules Nltk.pdf'}, lookup_index=0)]

# %% [markdown]
# # Thoughts : Everything seems to have failed for scanned

# %% [markdown]
# # Final : Custom

# %%
# !pip install pdfminer
import pdf2image
# Out:
# ...
#      |████████████████████████████████| 4.2 MB 6.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.4 MB 12.7 MB/s eta 0:00:01
# ...
#   Created wheel for pdfminer: filename=pdfminer-20191125-py3-none-any.whl size=6140072 sha256=9a560812ceda53857535b7bef02bd8759bb5bf57ef2551e028c8c5c715dd2d5d
#   Stored in directory: /Users/saumya/Library/Caches/pip/wheels/d1/aa/48/370f83a970d62355a2a47d2d640094a64eea932c22edae1891
# Successfully built pdfminer
# ...

# %% [markdown]
# ## Didn't work due to the error below.
# I tried my best to circumvent the error by installing all recommended libraries, still didnt work. the opencv that langchain/unstructured use is incompatible with their own versions

# %%
# !brew install libmagic
# !brew install poppler
# !brew install tesseract
# !brew install tesseract-lang
# !brew install --cask libreoffice
# !pip install "unstructured[local-inference]"
# !pip install tensorboard>=2.12.2
# !pip install "detectron2@git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2"
# Out:
# Running `brew update --auto-update`...
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# ast-grep            debugbreak          libabigail          yamlfmt
# convco              dzr                 libclc
# ==> New Casks
# llamachat                                smooze-pro
#
# You have 11 outdated formulae installed.
#
# ...
# To reinstall 5.44, run:
#   brew reinstall libmagic
# ...
# To reinstall 23.05.0, run:
#   brew reinstall poppler
# ...
# To reinstall 5.3.1, run:
#   brew reinstall tesseract
# ...
# To reinstall 4.1.0, run:
#   brew reinstall tesseract-lang
# ...
#
# To re-install libreoffice, run:
#   brew reinstall --cask libreoffice
# ...
#   Cloning https://github.com/facebookresearch/detectron2.git (to revision e2ce8dc) to /private/var/folders/s_/m0k5_mm955jcf0x7qf9858sc0000gn/T/pip-install-lolcappm/detectron2_6c6e1143b64b468296c745ec9d0c1722
# ...

# %%
from langchain.document_loaders.image import UnstructuredImageLoader

def convert_pdf_to_images(pdf_path):
    pages = pdf2image.convert_from_path(pdf_path)
    print(f"length: {len(pages)}")
    print(f"Type : {type(pages[0])}")
    doc = []
    for p in pages:
        loader = UnstructuredImageLoader(p)
        data = loader.load()
        doc.append(data)
    return doc

# %%
convert_pdf_to_images('/Users/saumya/Desktop/Programming/Data extraction/text/AllPDF/PdFextract copy 4/files/Ex-India Leave rules Nltk.pdf')
# Out:
# length: 7
# Type : <class 'PIL.PpmImagePlugin.PpmImageFile'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 convert_pdf_to_images('/Users/saumya/Desktop/Programming/Data extraction/text/AllPDF/PdFextract copy 4/files/Ex-India Leave rules Nltk.pdf')
#
# Cell In [33], line 10, in convert_pdf_to_images(pdf_path)
#       8 for p in pages:
#       9     loader = UnstructuredImageLoader(p)
# ---> 10     data = loader.load()
#      11     doc.append(data)
#      12 return doc
#
# File ~/miniconda3/lib/python3.9/site-packages/langchain/document_loaders/unstructured.py:61, in UnstructuredBaseLoader.load(self)
#      59 def load(self) -> List[Document]:
#      60     """Load file."""
# ---> 61     elements = self._get_elements()
#      62     if self.mode == "elements":
#      63         docs: List[Document] = list()
#
# ...
